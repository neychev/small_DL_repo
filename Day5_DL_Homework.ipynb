# %% [markdown]
# # Домашнее задание №5: Intro to DL

# %% [markdown]
# <span style="color: red; font-size: 14pt">Дедлайн: 24.02.2019 23:59</span>

# %% [markdown]
# **Оформление дз**:
#
# - Task short name: ``DL``.
# - Выполненное дз сохраните в файл ``ML2019_<фамилия>_HW#.ipynb``, к примеру -- ``ML2019_ivanov_HW5.ipynb``
# - Присылайте выполненное задание на почту `` ml_2019_q1@bigdatateam.org `` с темой письма `` HW# Short name. ФИО ``.
#
#     Например: `` HW5 DL. Иванов Иван Иванович. ``
#
# **Вопросы**:
# - Свои вопросы присылайте в Telegram.
#
# **Фидбек**:
# - Пожалуйста, оставьте свой отзыв после выполнения домашнего задания по сссылке:
#
#     http://bit.ly/ml2019q1_hw5_feedback

# %%
import sys
print(sys.version_info)

import keras
print(keras.__version__)
import numpy as np
import matplotlib.pyplot as plt

# %%
# Dirty Hack, uncomment if necessary

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
from keras import models
from keras import layers

# %%
from keras.datasets import fashion_mnist

# Загрузка данных (загруженные копии могут быть доступны в папке с семинарским занятием)
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# Смена размерности и нормировка
train_images = train_images.reshape((-1, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((-1, 28 * 28))
test_images = test_images.astype('float32') / 255

# Кодирование метки класса с помощью one-hot
from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# ## Часть 1. Практика с различными слоями (20%)
#
# Ниже Вам предлагается правильно задать параметры различных слоев нейронной сети для того, чтобы она могла эффективно обучаться на подаваемых данных. После каждой имплементации будет код для самопроверки, который позволит Вам отловить все ошибки до непосредственного построения нейронной сети.
#
# Выше данные уже были предобработаны аналогично семинару.

# %%
basic_input_shape = train_images[0].shape

# %% [markdown]
# Добавьте первый полносвязный слой из десяти нейронов в нейронную сеть (`layers.Dense`)

# %%
network = models.Sequential()
# your code here

# %%
# Проверим Вас
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
assert network.predict(train_images[0][None, :]).shape == (1, 10)
if network.predict(train_images[0][None, :]).shape == (1, 10):
    print('Отлично, все верно!')

# %% [markdown]
# Пусть теперь первый слой Вашей нейронной сети будет двумерной сверткой (`layers.Conv2D`). Параметры `filters` и `kernel_size` уже заданы в ячейке ниже, используйте их. В качестве функции активации используйте `relu`, параметр `padding='same'`.

# %%
input_shape_for_conv2d = [28, 28, 1]

# %% [markdown]
# Обратите внимание на документацию, для двумерного сверточного слоя требуется трехмерное изображение. Его размерность (H, W, C), где H и W это обычные координаты пикселя, а C - номер канала (в нашем случае изображения черно-белые, поэтому канал один. Для цветных изображений, например, каналов три - красный, зеленый и синий в палитре RGB).

# %%
reshaped_image_for_conv = train_images[0].reshape(input_shape_for_conv2d)

# %%
network = models.Sequential()
filters = 10
kernel_size = 5
# your code here

# %%
# Проверим Вас
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
assert network.predict(reshaped_image_for_conv[None, :]).shape == (1, 28, 28, 10)
if network.predict(reshaped_image_for_conv[None, :]).shape == (1, 28, 28, 10):
    print('Отлично, все верно!')

# %% [markdown]
# Теперь добавьте вслед за сверточным слоем (из предыдущего пункта) MaxPooling2D слой (`layers.MaxPooling2D`).

# %%
network = models.Sequential()
filters = 10
kernel_size = 5
# your code here

# %%
# Проверим Вас
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
assert network.predict(reshaped_image_for_conv[None, :]).shape == (1, 14, 14, 10)
if network.predict(reshaped_image_for_conv[None, :]).shape == (1, 14, 14, 10):
    print('Отлично, все верно!')

# %% [markdown]
# Возьмите нейронную сеть с прошлого шага и добавьте Flatten слой (`layers.Flatten`).

# %%
network = models.Sequential()
filters = 10
kernel_size = 5
# your code here

# %%
# Проверим Вас
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
assert network.predict(reshaped_image_for_conv[None, :]).shape == (1, 1960)
if network.predict(reshaped_image_for_conv[None, :]).shape == (1, 1960):
    print('Отлично, все верно!')

# %% [markdown]
# Возьмите нейронную сеть с прошлого шага и добавьте полносвязный слой из 64 нейронов и функцией активации `relu`.

# %%
network = models.Sequential()
filters = 10
kernel_size = 5
# your code here

# %%
# Проверим Вас
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
assert network.predict(reshaped_image_for_conv[None, :]).shape == (1, 64)
if network.predict(reshaped_image_for_conv[None, :]).shape == (1, 64):
    print('Отлично, все верно!')

# %% [markdown]
# Теперь добавьте Dropout слой после полносвязного (`layers.Dropout`) c `p=0.3`

# %%
network = models.Sequential()
filters = 10
kernel_size = 5
# your code here

# %%
# Проверим Вас
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
assert network.predict(reshaped_image_for_conv[None, :]).shape == (1, 64)
if network.predict(reshaped_image_for_conv[None, :]).shape == (1, 64):
    print('Отлично, все верно!')

# %% [markdown]
# И, наконец, добавьте в конец полносвязный слой из 10 нейронов с функцией активации `softmax`.

# %%
network = models.Sequential()
filters = 10
kernel_size = 5
# your code here

# %%
# Проверим Вас
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
assert network.predict(reshaped_image_for_conv[None, :]).shape == (1, 10)
if network.predict(reshaped_image_for_conv[None, :]).shape == (1, 10):
    print('Отлично, все верно!')

# %% [markdown]
# Давайте посмотрим на получившуюся модель:

# %%
network.summary()

# %% [markdown]
# А теперь обучим нейронную сеть и посмотрим на качество полученного классификатора:

# %% [markdown]
# Но перед этим нам необходимо привести `train_images`, `val_images` и `test_images` к нужным размерностям (теперь мы работаем с ними как с черно-белыми изображениями, а не векторами, помните?)

# %%
# Сделайте reshape для изображений, чтобы они подходили по формату к построенной нейронной сети.
# your code here (see above cells for hint)

# %% [markdown]
# Для выделения валидационной выборки достаточно указать параметр `validation_split` в методе `.fit`. See docs for more :)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128, ...)

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)

# %% [markdown]
# Точность полученного классификатора на отложенной выборке составляет:

# %%
print('test_acc:', test_acc)

# %% [markdown]
# Полученный результат превосходит (почти наверное) то, чего добилась простая полносвязная сеть на семинаре. Попробуем построить еще более точный классификатор!

# %% [markdown]
# ## Часть 2: beat'em up (80%)

# %% [markdown]
# Теперь ваша задача построить нейронную сеть, которая обеспечит хотя бы 90.5% метрики `accuracy` на тестовой выборке. Вы можете использовать построенную выше нейронную сеть в качестве baseline.

# %%
# your great code here

# %%
if test_acc >= 0.905:
    print('Congratulations! Look at the bottom of the notebook for some more challenges.')
else:
    print('Sorry, not enough. Look below if you have tried everything yet.')

# %% [markdown]
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# _______
# ### Spoiler alert!
# Если Вы перепробовали все, что пришло в голову, но 90.5% `accuracy` так и не покорились, попробуйте следующее:
# * Добавить еще один сверточный слой.
# * Увеличить размер Dense слоев (кроме последнего).
# * Поиграть с `rate` в Dropout слоях.
# * Увеличить число эпох.
# * Поменять алгоритм градиентного спуска (например, на adam).
# * Обратиться к вселенскому разуму в интернете.

# %% [markdown]
# ### For the brave one
# Если вы преуспели с предыдущим заданием и горите желеанием продолжить, попробуйте побить порог в 91.2% accuracy.
# Успехов!
#
# * Данный пункт задания опциональный, его решение не является обязательным.

# %%
# your brave code here

# %% [markdown]
# Пожалуйста, оцените данное домашнее задание: http://bit.ly/ml2019q1_hw5_feedback
